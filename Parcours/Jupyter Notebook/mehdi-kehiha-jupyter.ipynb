# %%
print ("coucou")
# Out:
# coucou

# %% [markdown]
# # Mon premier notebook
#
# ## Présentation
#
# Je découvre **Python** avec *Jupyter Notebook*.
#  - une cellule de code ; - une cellule Markdown ; - un premier résultat.
#
# [Site officiel de Python](https://www.python.org)
